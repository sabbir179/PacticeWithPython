# %% [markdown]
# <a href="https://colab.research.google.com/github/sabbir179/practiceWithPython/blob/main/Penguin_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### INSTALL AND IMPORT LIBRARIES

# %% [markdown]
# This demonstration requires the "palmerpenguins" libraby, which can be installed with Python's pip commond. this command only need to be the once per machine.

# %%
pip install palmerpenguins
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Once "palmerpenguins" is installed, then load the libraries below.

# %%
from palmerpenguins import load_penguins     # For penguins dataset
import pandas as pd                          # For dataframes
import matplotlib.pyplot as plt              # For plotting functions
import seaborn as sns                        # For addintional plotting functions

# %% [markdown]
# LOAD AND PREPARE DATA

# %% [markdown]
# For all three  demonstrations of clustering, we'll use the **penguins** dataset, which is available in the **palmerpenguins** package. It is also described at "https://py.pi.org/project/palmerpenguins
#
# Following steps are used to prepare the data:
#
# 1. Load the **penguins** dataset in variable **df**
# 2. Remove the **island**, **year**, and **sex** variables
# 3. Rename the class variable **species** as y
# 4. Drop all rows with **NaN**
# 5. Display the frist 5 rows of **df**

# %%
# Loads the penguins dataset
df = load_penguins()

# Drop variables and NaN cases, rename variable
df = df.drop(['island', 'year', 'sex'], axis=1) \
    .dropna() \
    .rename(columns={'species': 'y'})

# Displays the firts 5 rows of data
df.head()
# Out:
#         y  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0  Adelie            39.1           18.7              181.0       3750.0
# 1  Adelie            39.5           17.4              186.0       3800.0
# 2  Adelie            40.3           18.0              195.0       3250.0
# 4  Adelie            36.7           19.3              193.0       3450.0
# 5  Adelie            39.3           20.6              190.0       3650.0

# %% [markdown]
# ### **EXPLORE THE DATA**

# %% [markdown]
# Visualize various aspects of penguins dataset

# %% [markdown]
# ### **Bar Plot of Class Variable**
#
# Use Seaborn's **countplot** function to create a bar plot and look at the distribution of different species

# %%
sns.countplot(x='y', data=df)

# %% [markdown]
# ### **Creates a grid using Seaborn's PairGrid()**
#
# Plot the relationships between all features using **PairGrid**. In particular, notice how **bill_length_mm**, and **bill_depth_mm** variables are good at distinguishing betweeb the species.

# %%
# Creates a grid using Seaborn's PairGrid()
g = sns.PairGrid(
    df,
    vars = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'],
    hue = 'y',
    diag_sharey = False,
    palette=["red", "green", "blue"]
)

# Add histograms on the diagonal
g.map_diag(plt.hist)

# Adds density plots above the diagonal
g.map_upper(sns.kdeplot)

# Adds scatterplots below the diagonal
g.map_lower(sns.scatterplot)

# Adds a legend
g.add_legend()
